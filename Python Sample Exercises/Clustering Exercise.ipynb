# %% [markdown]
# # Clustering Exercise

# %% [markdown]
# ## In this exercise a dataset containing salary and occupation data was uploaded then machine learning was used to cluster individuals in the dataset based on years of experience and salaries. The exercise focused on clustering more so than thorough analysis. In the exploratory stage, a scatter plot was used to eye-ball for correlation and direction. In a real-world example, regression analysis would have been conducted to support impressions.

# %%
import pandas as pd 
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 from sklearn.cluster import KMeans
#       3 from sklearn.preprocessing import MinMaxScaler
# ----> 4 from matplotlib import pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install scikit-learn==1.1.0
# Out:
# ...
#   Using cached scikit_learn-1.1.0-cp39-cp39-macosx_12_0_arm64.whl (7.6 MB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# ...

# %%
sklearn.preprocessing.
# Out:
#   Cell In[3], line 1
#     sklearn.preprocessing.
#                           ^
# SyntaxError: invalid syntax

# %%
# !pip install --upgrade scikit-learn

# %%
df = pd.read_csv('Salary Data.csv')
df.dropna(inplace=True)
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
plt.scatter(df['Years of Experience'],df['Salary'])

# %%
df[260:270]
# Out:
#       Age  Gender Education Level                     Job Title  \
# 262  46.0    Male             PhD         Senior Data Scientist
# 263  31.0  Female      Bachelor's  Junior Marketing Coordinator
# 264  42.0    Male      Bachelor's     Senior Operations Manager
# 265  29.0  Female      Bachelor's   Junior Sales Representative
# 266  36.0    Male      Bachelor's   Senior Marketing Specialist
# 267  44.0  Female        Master's          Senior HR Specialist
# 268  33.0    Male      Bachelor's     Junior Operations Manager
# 269  39.0  Female      Bachelor's  Senior Marketing Coordinator
# 270  45.0    Male             PhD          Senior Data Engineer
# 271  32.0  Female      Bachelor's      Junior Marketing Manager
#
#      Years of Experience    Salary
# 262                 18.0  160000.0
# 263                  3.0   50000.0
# 264                 12.0  110000.0
# 265                  1.5   40000.0
# 266                  8.0   95000.0
# 267                 15.0  140000.0
# ...

# %%
km = KMeans(n_clusters=5)
y = km.fit_predict(df[['Years of Experience','Salary']])
y
# Out:
# array([4, 0, 1, 0, 3, 0, 2, 4, 0, 2, 4, 2, 0, 2, 0, 2, 4, 2, 0, 1, 4, 1,
#        0, 0, 2, 0, 2, 0, 2, 4, 3, 0, 4, 0, 1, 0, 0, 2, 0, 1, 4, 1, 0, 0,
#        2, 0, 4, 1, 2, 0, 2, 4, 0, 3, 0, 4, 0, 2, 0, 4, 1, 0, 4, 1, 0, 4,
#        2, 0, 4, 1, 0, 4, 1, 0, 2, 4, 1, 4, 1, 0, 4, 4, 0, 3, 0, 4, 0, 4,
#        2, 0, 2, 0, 4, 1, 4, 0, 1, 0, 4, 2, 0, 4, 1, 0, 4, 3, 0, 0, 4, 0,
#        2, 4, 2, 4, 0, 4, 0, 1, 0, 2, 4, 1, 0, 4, 2, 0, 4, 2, 0, 4, 1, 0,
#        4, 1, 0, 0, 2, 0, 0, 2, 0, 2, 0, 2, 0, 4, 1, 0, 4, 1, 0, 2, 2, 0,
#        4, 2, 0, 2, 1, 0, 4, 1, 0, 4, 2, 0, 2, 1, 0, 4, 1, 0, 2, 0, 4, 2,
#        0, 4, 1, 0, 4, 2, 0, 4, 2, 4, 4, 1, 0, 4, 1, 0, 4, 2, 0, 4, 1, 0,
#        2, 1, 0, 2, 0, 4, 1, 0, 2, 1, 0, 2, 1, 0, 4, 2, 4, 4, 1, 0, 4, 1,
#        0, 4, 2, 0, 4, 1, 4, 2, 1, 0, 2, 0, 4, 2, 0, 4, 2, 4, 2, 1, 0, 2,
#        1, 4, 4, 1, 0, 4, 1, 0, 2, 1, 0, 4, 2, 4, 4, 1, 0, 2, 1, 0, 2, 0,
#        4, 2, 0, 2, 1, 0, 4, 1, 0, 2, 1, 4, 4, 1, 0, 4, 1, 0, 4, 1, 0, 4,
# ...

# %%
df['cluster'] = y
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary  cluster
# 0   90000.0        4
# 1   65000.0        0
# 2  150000.0        1
# 3   60000.0        0
# 4  200000.0        3

# %%
# Displaying clusters on graph
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1['Years of Experience'],df1['Salary'], color = 'green')
plt.scatter(df2['Years of Experience'],df2['Salary'], color = 'red')
plt.scatter(df3['Years of Experience'],df3['Salary'], color = 'black')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df1
# Out:
#       Age  Gender Education Level                 Job Title  \
# 1    28.0  Female        Master's              Data Analyst
# 3    36.0  Female      Bachelor's           Sales Associate
# 5    29.0    Male      Bachelor's         Marketing Analyst
# 8    26.0  Female      Bachelor's     Marketing Coordinator
# 12   35.0    Male      Bachelor's         Financial Analyst
# ..    ...     ...             ...                       ...
# 357  33.0    Male      Bachelor's    Junior Product Manager
# 360  29.0  Female      Bachelor's    Junior Project Manager
# 366  31.0  Female      Bachelor's  Junior Financial Analyst
# 369  33.0    Male      Bachelor's   Junior Business Analyst
# 372  29.0  Female      Bachelor's    Junior Project Manager
#
#      Years of Experience   Salary  cluster
# 1                    3.0  65000.0        0
# 3                    7.0  60000.0        0
# 5                    2.0  55000.0        0
# 8                    1.0  45000.0        0
# ...
